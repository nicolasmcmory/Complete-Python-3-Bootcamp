# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Warmup Project Exercise

# %% [markdown]
# ## Simple War Game
#
# Before we launch in to the OOP Milestone 2 Project, let's walk through together on using OOP for a more robust and complex application, such as a game. We will use Python OOP to simulate a simplified version of the game war. Two players will each start off with half the deck, then they each remove a card, compare which card has the highest value, and the player with the higher card wins both cards. In the event of a time

# %% [markdown]
# ## Single Card Class
#
# ### Creating a Card Class with outside variables
#
# Here we will use some outside variables that we know don't change regardless of the situation, such as a deck of cards. Regardless of what round,match, or game we're playing, we'll still need the same deck of cards.

# %%
# We'll use this later
import random

# %%
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:

    def __init__(self, suit: str, rank: str):
        """ instance vars: suit, rank, value (value of card linked to dict by rank as key) """
        self.suit = suit
        self.rank = rank
        self.value = values[rank.capitalize()]

    def __str__(self):
        return f"{self.rank} of {self.suit}"

# %% [markdown]
# Create an example card

# %%
suits[0]
# Out:
# 'Hearts'

# %%
ranks[0]
# Out:
# 'Two'

# %%
two_hearts = Card(suits[0], ranks[0])
three_hearts = Card(suits[0], ranks[1])

# %%
two_hearts

# %%
print(two_hearts)
# Out:
# Two of Hearts

# %%
two_hearts.rank
# Out:
# 'Two'

# %%
two_hearts.value < three_hearts.value
# Out:
# True

# %%
values[two_hearts.rank]
# Out:
# 2

# %% [markdown]
# ## Deck Class
#
# ### Using a class within another class
#
# We just created a single card, but how can we create an entire Deck of cards? Let's explore doing this with a class that utilizes the Card class.

# %% [markdown]
# A Deck will be made up of multiple Cards. Which mean's we will actually use the Card class within the \_\_init__ of the Deck class.

# %%
class Deck:
    def __init__(self):
        # list of cards = deck
        self.all_cards = []
        # create all cards from global tuples
        for suit in suits:
            for rank in ranks:
                card = Card(suit, rank)
                self.all_cards.append(card)

    def __str__(self):
        deck_str = "\n".join([f"{card}" for card in self.all_cards])
        return deck_str

    def shuffle(self):
        """Shuffles deck in place.
        Recall shuffle method, shuffles list items in place, mutating the list itself.
        """
        random.shuffle(self.all_cards)

    def __len__(self):
        return len(self.all_cards)

    def deal_one(self):
        """Deals card from top of deck (cards facing down)"""
        return self.all_cards.pop()

# %% [markdown]
# ### Create a Deck

# %%
mydeck = Deck()

# %%
len(mydeck.all_cards)
# Out:
# 52

# %%
mydeck.all_cards[0]

# %%
print(mydeck.all_cards[-1])
# Out:
# Ace of Clubs

# %%
mydeck.shuffle()

# %%
print(mydeck.all_cards[-1])
# Out:
# King of Spades

# %%
my_card = mydeck.deal_one()

# %%
print(my_card)
# Out:
# King of Spades

# %% [markdown]
# # Player Class
#
# Let's create a Player Class, a player should be able to hold instances of Cards, they should also be able to remove and add them from their hand. We want the Player class to be flexible enough to add one card, or many cards so we'll use a simple if check to keep it all in the same method.

# %% [markdown]
# We'll keep this all in mind as we create the methods for the Player class.
#
# ### Player Class

# %%
class Player:
    def __init__(self, name: str):
        self.name = name
        self.all_cards = []

    def remove_one(self):
        return self.all_cards.pop(0)

    def add_cards(self, new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
        return self.__str__()

    def __str__(self):
        return f"Player {self.name} has {len(self.all_cards)} card(s) in hand."

# %%
jose = Player("Jose")

# %%
jose

# %%
print(jose)
# Out:
# Player Jose has 0 card(s) in hand.

# %%
two_hearts
print(two_hearts)
# Out:
# Two of Hearts

# %%
jose.add_cards(two_hearts)
# Out:
# 'Player Jose has 1 card(s) in hand.'

# %%
print(jose)
# Out:
# Player Jose has 1 card(s) in hand.

# %%
jose.add_cards([two_hearts,two_hearts,two_hearts])
# Out:
# 'Player Jose has 4 card(s) in hand.'

# %%
print(jose)
# Out:
# Player Jose has 4 card(s) in hand.

# %% [markdown]
# ## War Game Logic

# %%
player_one = Player("Jim")

# %%
player_two  = Player("Tom")

# %% [markdown]
# ## Setup New Game

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %% [markdown]
# ### Split the Deck between players

# %%
half_deck_size = int(len(new_deck)/2)
print(half_deck_size)
# Out:
# 26

# %%
for hand_out in range(half_deck_size):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
print(len(new_deck))
# Out:
# 0

# %%
print(player_one)
# Out:
# Player Jim has 26 card(s) in hand.

# %%
print(player_two)
# Out:
# Player Tom has 26 card(s) in hand.

# %% [markdown]
# ## Play the Game

# %%
import pdb

# %%
game_on = True

# %%
round_num = 0

while game_on:

    if len(player_one.all_cards) == 0:
        print(f"{player_two.name} wins.")
        game_on = False
        break
    if len(player_two.all_cards) == 0:
        print(f"{player_one.name} wins.")
        game_on = False
        break

    # Start new round
    round_num += 1
    print(f"Round {round_num}")

    player_one_cards_in_play = []
    player_one_cards_in_play.append(player_one.remove_one())

    player_two_cards_in_play = []
    player_two_cards_in_play.append(player_two.remove_one())

    # Enter comparison, payers both need more than 1 card to play
    while game_on:

        # Last card added to table (face up) is the one used to compare
        # Player one's card is more valuable, player one wins and takes all
        if player_one_cards_in_play[-1].value > player_two_cards_in_play[-1].value:
            print(player_one)
            player_one.add_cards(player_one_cards_in_play)
            player_one.add_cards(player_two_cards_in_play)
            break
        # Player two's card is more valuable, player two wins and takes all
        elif player_one_cards_in_play[-1].value < player_two_cards_in_play[-1].value:
            print(player_two)
            player_two.add_cards(player_two_cards_in_play)
            player_two.add_cards(player_one_cards_in_play)
            break
        # Both player's cards have the same value. War ensues,
        else:
            print("War! Each will play 5 cards, the last one is used to compare.")
            log_no_play = " doesn't have enough cards to play, they loose!"

            if len(player_one.all_cards) < 5:
                print(player_one.name, log_no_play)
                game_on = False
                break
            elif len(player_two.all_cards) < 5:
                print(player_two.name, log_no_play)
                game_on = False
                break
            else:
                for num in range(5):
                    player_one_cards_in_play.append(player_one.remove_one())
                    player_two_cards_in_play.append(player_two.remove_one())
# Out:
# Round 1
# Player Tom has 25 card(s) in hand.
# Round 2
# Player Jim has 24 card(s) in hand.
# Round 3
# Player Tom has 25 card(s) in hand.
# Round 4
# Player Tom has 26 card(s) in hand.
# Round 5
# Player Tom has 27 card(s) in hand.
# Round 6
# Player Jim has 22 card(s) in hand.
# Round 7
# Player Jim has 23 card(s) in hand.
# Round 8
# Player Tom has 26 card(s) in hand.
# Round 9
# Player Jim has 23 card(s) in hand.
# Round 10
# Player Tom has 26 card(s) in hand.
# Round 11
# Player Jim has 23 card(s) in hand.
# Round 12
# Player Jim has 24 card(s) in hand.
# Round 13
# Player Jim has 25 card(s) in hand.
# Round 14
# Player Tom has 24 card(s) in hand.
# Round 15
# Player Jim has 25 card(s) in hand.
# Round 16
# Player Tom has 24 card(s) in hand.
# Round 17
# Player Tom has 25 card(s) in hand.
# Round 18
# Player Tom has 26 card(s) in hand.
# Round 19
# Player Jim has 23 card(s) in hand.
# Round 20
# War! Each will play 5 cards, the last one is used to compare.
# Player Tom has 21 card(s) in hand.
# Round 21
# War! Each will play 5 cards, the last one is used to compare.
# Player Jim has 13 card(s) in hand.
# Round 22
# Player Jim has 24 card(s) in hand.
# Round 23
# Player Jim has 25 card(s) in hand.
# Round 24
# Player Jim has 26 card(s) in hand.
# Round 25
# Player Tom has 23 card(s) in hand.
# Round 26
# Player Jim has 26 card(s) in hand.
# Round 27
# Player Tom has 23 card(s) in hand.
# Round 28
# Player Tom has 24 card(s) in hand.
# Round 29
# Player Jim has 25 card(s) in hand.
# Round 30
# Player Jim has 26 card(s) in hand.
# Round 31
# Player Tom has 23 card(s) in hand.
# Round 32
# Player Jim has 26 card(s) in hand.
# Round 33
# Player Jim has 27 card(s) in hand.
# Round 34
# War! Each will play 5 cards, the last one is used to compare.
# Player Tom has 17 card(s) in hand.
# Round 35
# Player Jim has 22 card(s) in hand.
# Round 36
# Player Tom has 27 card(s) in hand.
# Round 37
# Player Jim has 22 card(s) in hand.
# Round 38
# Player Tom has 27 card(s) in hand.
# Round 39
# Player Tom has 28 card(s) in hand.
# Round 40
# Player Tom has 29 card(s) in hand.
# Round 41
# Player Tom has 30 card(s) in hand.
# Round 42
# Player Jim has 19 card(s) in hand.
# Round 43
# Player Tom has 30 card(s) in hand.
# Round 44
# Player Tom has 31 card(s) in hand.
# Round 45
# Player Tom has 32 card(s) in hand.
# Round 46
# Player Tom has 33 card(s) in hand.
# Round 47
# Player Tom has 34 card(s) in hand.
# Round 48
# Player Tom has 35 card(s) in hand.
# Round 49
# Player Jim has 14 card(s) in hand.
# Round 50
# Player Tom has 35 card(s) in hand.
# Round 51
# Player Tom has 36 card(s) in hand.
# Round 52
# Player Jim has 13 card(s) in hand.
# Round 53
# Player Tom has 36 card(s) in hand.
# Round 54
# Player Tom has 37 card(s) in hand.
# Round 55
# Player Tom has 38 card(s) in hand.
# Round 56
# Player Jim has 11 card(s) in hand.
# Round 57
# Player Jim has 12 card(s) in hand.
# Round 58
# Player Jim has 13 card(s) in hand.
# Round 59
# Player Jim has 14 card(s) in hand.
# Round 60
# Player Tom has 35 card(s) in hand.
# Round 61
# War! Each will play 5 cards, the last one is used to compare.
# Player Tom has 31 card(s) in hand.
# Round 62
# Player Tom has 42 card(s) in hand.
# Round 63
# Player Jim has 7 card(s) in hand.
# Round 64
# Player Jim has 8 card(s) in hand.
# Round 65
# Player Jim has 9 card(s) in hand.
# Round 66
# Player Jim has 10 card(s) in hand.
# Round 67
# Player Tom has 39 card(s) in hand.
# Round 68
# Player Jim has 10 card(s) in hand.
# Round 69
# Player Jim has 11 card(s) in hand.
# Round 70
# War! Each will play 5 cards, the last one is used to compare.
# Player Tom has 33 card(s) in hand.
# Round 71
# Player Tom has 44 card(s) in hand.
# Round 72
# Player Jim has 5 card(s) in hand.
# Round 73
# Player Jim has 6 card(s) in hand.
# Round 74
# Player Tom has 43 card(s) in hand.
# Round 75
# Player Tom has 44 card(s) in hand.
# Round 76
# Player Tom has 45 card(s) in hand.
# Round 77
# Player Tom has 46 card(s) in hand.
# Round 78
# Player Tom has 47 card(s) in hand.
# Round 79
# War! Each will play 5 cards, the last one is used to compare.
# Jim  doesn't have enough cards to play, they loose!

# %% [markdown]
# ## Game Setup in One Cell

# %%
player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())
    
game_on = True

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    still_comparing = True

    while still_comparing:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            still_comparing = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            still_comparing = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[750], line 34
#      29 still_comparing = True
#      31 while still_comparing:
# ---> 34     if player_one_cards[-1].value > player_two_cards[-1].value:
#      35
#      36         # Player One gets the cards
#      37         player_one.add_cards(player_one_cards)
#      38         player_one.add_cards(player_two_cards)
#
# AttributeError: 'tuple' object has no attribute 'value'

# %%
len(player_one.all_cards)
# Out:
# 27

# %%
len(player_two.all_cards)
# Out:
# 25

# %%
print(player_one_cards[-1])
# Out:
# Ace of Diamonds

# %%
print(player_two_cards[-1])
# Out:
# Four of Hearts

# %% [markdown]
# ## Great Work!
#
# Other links that may interest you:
# * https://www.reddit.com/r/learnpython/comments/7ay83p/war_card_game/
# * https://codereview.stackexchange.com/questions/131174/war-card-game-using-classes
# * https://gist.github.com/damianesteban/6896120
# * https://lethain.com/war-card-game-in-python/
# * https://hectorpefo.github.io/2017-09-13-Card-Wars/
# * https://www.wimpyprogrammer.com/the-statistics-of-war-the-card-game
