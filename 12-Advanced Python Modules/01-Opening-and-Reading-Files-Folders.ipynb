# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Opening and Reading Files
#
# So far we've discussed how to open files manually, one by one. Let's explore how we can open files programatically.

# %% [markdown]
# _____

# %% [markdown]
# ### Review: Understanding File Paths

# %%
pwd
# Out:
# '/home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules'

# %% [markdown]
# ### Create Practice File
#
# We will begin by creating a practice text file that we will be using for demonstration.

# %%
f = open('practice.txt','w+')

# %%
f.write('test')
f.close()

# %% [markdown]
# ### Getting Directories
#
# Python has a built-in [os module](https://docs.python.org/3/library/os.html) that allows us to use operating system dependent functionality.
#
# You can get the current directory:

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules'

# %% [markdown]
# ### Listing Files in a Directory
#
# You can also use the os module to list directories.

# %%
# In your current directory
os.listdir()
# Out:
# ['01-Opening-and-Reading-Files-Folders.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '02-Datetime-Module.ipynb',
#  'Example_Top_Level',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  '00-Collections-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '.ipynb_checkpoints']

# %%
# In any directory you pass
os.listdir('/home/NICO/GitHubDebian/Complete-Python-3-Bootcamp')
# Out:
# ['README.md',
#  'Jupyter (iPython) Notebooks Guide.ipynb',
#  'Pierian_Data_Logo.png',
#  'practice.txt',
#  'Requirements.txt',
#  '11-Python Generators',
#  '03-Methods and Functions',
#  '08-Milestone Project - 2',
#  '06-Modules and Packages',
#  '16-Emailing-with-Python',
#  '18-Milestone Project - 3',
#  '04-Milestone Project - 1',
#  '.venv',
#  '00-Python Object and Data Structure Basics',
#  '12-Advanced Python Modules',
#  '02-Python Statements',
#  '13-Web-Scraping',
#  '.gitignore',
#  '10-Python Decorators',
#  '05-Object Oriented Programming',
#  '17-Advanced Python Objects and Data Structures',
#  '09-Empty-Section-Skip',
#  '15-PDFs-and-Spreadsheets',
#  '14-Working-with-Images',
#  '07-Errors and Exception Handling',
#  '.git',
#  '01-Python Comparison Operators',
#  '19-Bonus Material - Introduction to GUIs',
#  '.ipynb_checkpoints']

# %% [markdown]
# ### Moving Files
#
# You can use the built-in **shutil** module to to move files to different locations. Keep in mind, there are permission restrictions, for example if you are logged in a User A, you won't be able to make changes to the top level Users folder without the proper permissions, [more info](https://stackoverflow.com/questions/23253439/shutil-movescr-dst-gets-me-ioerror-errno-13-permission-denied-and-3-more-e)

# %%
import shutil
os.listdir()
# Out:
# ['practice.txt',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '02-Datetime-Module.ipynb',
#  'Example_Top_Level',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  '00-Collections-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '.ipynb_checkpoints']

# %%
shutil.move('practice.txt','/home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/move_practice')
# Out:
# '/home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/move_practice/practice.txt'

# %%
os.listdir()
# Out:
# ['01-Opening-and-Reading-Files-Folders.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '02-Datetime-Module.ipynb',
#  'Example_Top_Level',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  '00-Collections-Module.ipynb',
#  'move_practice',
#  '03-Math-and-Random-Module.ipynb',
#  '.ipynb_checkpoints']

# %%
shutil.move('C:\\Users\\Marcial\practice.txt',os.getcwd())
# Out:
# 'C:\\Users\\Marcial\\Pierian-Data-Courses\\Complete-Python-3-Bootcamp\\12-Advanced Python Modules\\practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt',
#  'practice.txt']

# %% [markdown]
# ### Deleting Files
# ____
# **NOTE: The os module provides 3 methods for deleting files:**
# * os.unlink(path) which deletes a file at the path your provide
# * os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# * shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path.
# **All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.**
# ___
#
# Install the send2trash module with:
#
#     pip install send2trash
#
# at your command line.

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt',
#  'practice.txt']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt']

# %% [markdown]
# ### Walking through a directory
#
# Often you will just need to "walk" through a directory, that is visit every file or folder and check to see if a file is in the directory, and then perhaps do something with that file. Usually recursively walking through every file and folder in a directory would be quite tricky to program, but luckily the os module has a direct method call for this called os.walk(). Let's explore how it works.

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 os.getcwd()
#
# NameError: name 'os' is not defined

# %%
os.listdir()
# Out:
# ['01-Opening-and-Reading-Files-Folders.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '02-Datetime-Module.ipynb',
#  'Example_Top_Level',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  '00-Collections-Module.ipynb',
#  'move_practice',
#  '03-Math-and-Random-Module.ipynb',
#  '.ipynb_checkpoints']

# %%
for folder, sub_folders, files in os.walk(os.getcwd()):
    print(f"Currently looking at: {folder}\n\nThe subfolders are:")
    for sub_folder in sub_folders:
        print(f"\tSubfolder: {sub_folder}")
    print(f"\nThe files are:")
    for f in files:
        print(f"\tFile: {f}")
    print("")
# Out:
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules
#
# The subfolders are:
# 	Subfolder: Example_Top_Level
# 	Subfolder: 08-Advanced-Python-Module-Exercise
# 	Subfolder: .ipynb_checkpoints
#
# The files are:
# 	File: 01-Opening-and-Reading-Files-Folders.ipynb
# 	File: 06-Timing your code - timeit.ipynb
# 	File: 04-Python Debugger (pdb).ipynb
# 	File: 05-Overview-of-Regular-Expressions.ipynb
# 	File: 02-Datetime-Module.ipynb
# 	File: 07-Unzipping-and-Zipping-Files.ipynb
# 	File: 00-Collections-Module.ipynb
# 	File: 03-Math-and-Random-Module.ipynb
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/Example_Top_Level
#
# The subfolders are:
# 	Subfolder: Mid-Example-One
#
# The files are:
# 	File: Mid-Example.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/Example_Top_Level/Mid-Example-One
#
# The subfolders are:
# 	Subfolder: Bottom-Level-One
# 	Subfolder: Bottom-Level-Two
#
# The files are:
# 	File: Mid-Level-Doc.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/Example_Top_Level/Mid-Example-One/Bottom-Level-One
#
# The subfolders are:
#
# The files are:
# 	File: One_Text.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/Example_Top_Level/Mid-Example-One/Bottom-Level-Two
#
# The subfolders are:
#
# The files are:
# 	File: Bottom-Text-Two.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise
#
# The subfolders are:
# 	Subfolder: extracted_content
# 	Subfolder: .ipynb_checkpoints
#
# The files are:
# 	File: 08-Advanced-Modules-Exercise-Solutions.ipynb
# 	File: 07-Advanced-Modules-Exercise-Puzzle.ipynb
# 	File: unzip_me_for_instructions.zip
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content
#
# The subfolders are:
# 	Subfolder: Five
# 	Subfolder: Two
# 	Subfolder: One
# 	Subfolder: Four
# 	Subfolder: Three
#
# The files are:
# 	File: Instructions.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Five
#
# The subfolders are:
#
# The files are:
# 	File: BTYWAHLHKBM.txt
# 	File: DZUWWXYIAEL.txt
# 	File: AXJGVPVEFAS.txt
# 	File: BUGKBZWRRVI.txt
# 	File: COMGMZBJAYE.txt
# 	File: BNUQEHCFRTG.txt
# 	File: AQKATDFGXTS.txt
# 	File: ETCUEXWNBCF.txt
# 	File: DDLASODUVPX.txt
# 	File: CXBVCTRBBIE.txt
# 	File: BSKJDRNEZQM.txt
# 	File: DQPZQLBCJYP.txt
# 	File: DYOPIIVMZOO.txt
# 	File: BVBURZZCAPR.txt
# 	File: APJKSRITGGX.txt
# 	File: CSCLFZCDYYC.txt
# 	File: ESIZWBHMGDP.txt
# 	File: EYTCGIOYWIW.txt
# 	File: EIPWXMQZJKU.txt
# 	File: ARLKFCWIAJE.txt
# 	File: EAAOEPSAWMQ.txt
# 	File: DHZBAAYEADM.txt
# 	File: CRFSDGYFSHA.txt
# 	File: AEITMYIRQLP.txt
# 	File: CAHBEVSVDDN.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Two
#
# The subfolders are:
#
# The files are:
# 	File: OMWIMVRCMYM.txt
# 	File: HMUTDOVNYTV.txt
# 	File: GXYSEPAFRTP.txt
# 	File: HTOHSTYXTCO.txt
# 	File: LCJZYDHBFRM.txt
# 	File: GKQBQRCTNNK.txt
# 	File: LYZEQCVYNEZ.txt
# 	File: LULTNYAQEJG.txt
# 	File: LSQSTGPIGIY.txt
# 	File: GTOTCIWMDBY.txt
# 	File: HEORIXOTANT.txt
# 	File: HARDNJGDRBC.txt
# 	File: OKWFOOYTXFU.txt
# 	File: GMMQQUBMJNR.txt
# 	File: GQTJJORZBXY.txt
# 	File: OYMAGXAGWHJ.txt
# 	File: OHZOUOSFJQC.txt
# 	File: SOFUJYXTIMK.txt
# 	File: OIHMLGMWTHL.txt
# 	File: SWOFXREEHWA.txt
# 	File: SPDZYGDHEWO.txt
# 	File: LVMBINRBJXL.txt
# 	File: HMZXPBOPRAE.txt
# 	File: SIKFPPLCJDN.txt
# 	File: SJMJLDGPBSJ.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/One
#
# The subfolders are:
#
# The files are:
# 	File: PDJMSMNKIRM.txt
# 	File: PTOBBCJYURJ.txt
# 	File: JTHSNBNPQSE.txt
# 	File: PHWAVPEKAER.txt
# 	File: HDOHZHFSTTK.txt
# 	File: LPNDVDXPZIG.txt
# 	File: JDLRVFCXYLU.txt
# 	File: LFEATJAAYDC.txt
# 	File: HMNZTLIFGPD.txt
# 	File: KFIUZFERLET.txt
# 	File: LIFDHOFKWOI.txt
# 	File: PQNVCVJINAR.txt
# 	File: HFUTPPAXDIS.txt
# 	File: HRQFTHKVJTL.txt
# 	File: PLYCGPVEAWO.txt
# 	File: KCXGNQCZBLO.txt
# 	File: KMMLGJOWLGI.txt
# 	File: JEHBLZPUPSP.txt
# 	File: HVUTZEVMSBW.txt
# 	File: KTXDHIOKAUI.txt
# 	File: LHODFIKVTQA.txt
# 	File: LDGOCUQJNNS.txt
# 	File: JQUOBKFUACN.txt
# 	File: JLTXKIGCWDL.txt
# 	File: KNBSKDREHQU.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Four
#
# The subfolders are:
#
# The files are:
# 	File: QTDYYIFPHAU.txt
# 	File: QVNJULGXNUM.txt
# 	File: EMTGPSXQEJX.txt
# 	File: WHTOHQUWXIN.txt
# 	File: QDDETWBHJYC.txt
# 	File: RXDARIDGKBF.txt
# 	File: TJFMLJODVAD.txt
# 	File: TKCZSFQNJTX.txt
# 	File: ROICPTWKXDX.txt
# 	File: REAXWSOIQDY.txt
# 	File: QCWCFLKNZMN.txt
# 	File: QCTCKDIBBVG.txt
# 	File: ESDIZXHYCVY.txt
# 	File: WXDJDOGZEHN.txt
# 	File: EPRNUHRSESC.txt
# 	File: ECIOBYCDVFI.txt
# 	File: RYNXFYXMKHG.txt
# 	File: WYDLGSGGXKV.txt
# 	File: EXVQSVBQQQH.txt
# 	File: THPNEGKTJWI.txt
# 	File: WNJISWPEBRS.txt
# 	File: RSXOTNGKBML.txt
# 	File: TAKNAVDMZKV.txt
# 	File: TWUOYFCCYBQ.txt
# 	File: WFSKPTXPFCH.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Three
#
# The subfolders are:
#
# The files are:
# 	File: XVMPVSVYKFR.txt
# 	File: YYIZGBTQHZP.txt
# 	File: ZEZKKRBIZEB.txt
# 	File: XHZPVUQTXIO.txt
# 	File: YCESZHJDBXH.txt
# 	File: ZXIBJMPROKW.txt
# 	File: XFHJOTNPEJG.txt
# 	File: VVKGWLRMHLU.txt
# 	File: ZXEZRQXZNPG.txt
# 	File: XAJMCPEWFNI.txt
# 	File: ZKQJXAYKPVD.txt
# 	File: VCFJCGJFBIH.txt
# 	File: YQBIUHSUEVW.txt
# 	File: VSXFSTABZDY.txt
# 	File: YDQFMWXOUMW.txt
# 	File: XJCWENFFGHB.txt
# 	File: VVHFVZUNLOO.txt
# 	File: VAQIJTDOFUJ.txt
# 	File: YQRNCMNFFHW.txt
# 	File: ZOWVXWPOGWP.txt
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/.ipynb_checkpoints
#
# The subfolders are:
#
# The files are:
# 	File: 08-Advanced-Modules-Exercise-Solutions-checkpoint.ipynb
# 	File: 07-Advanced-Modules-Exercise-Puzzle-checkpoint.ipynb
#
# Currently looking at: /home/NICO/GitHubDebian/Complete-Python-3-Bootcamp/12-Advanced Python Modules/.ipynb_checkpoints
#
# The subfolders are:
#
# The files are:
# 	File: 03-Math-and-Random-Module-checkpoint.ipynb
# 	File: 04-Python Debugger (pdb)-checkpoint.ipynb
# 	File: 05-Overview-of-Regular-Expressions-checkpoint.ipynb
# 	File: 07-Unzipping-and-Zipping-Files-checkpoint.ipynb
# 	File: 07-OS-Module-checkpoint.ipynb
# 	File: 09-Advanced-Modules-Exercise-Solutions-checkpoint.ipynb
# 	File: 00-Collections-Module-checkpoint.ipynb
# 	File: 01-Datetime-Module-checkpoint.ipynb
# 	File: 04-Timing your code - timeit-checkpoint.ipynb
# 	File: 01-Opening-and-Reading-Files-Folders-checkpoint.ipynb
# 	File: 03-Python Debugger (pdb)-checkpoint.ipynb
# 	File: 06-Unzipping-and-Zipping-Files-checkpoint.ipynb
# 	File: 06-Timing your code - timeit-checkpoint.ipynb
# 	File: 02-Datetime-Module-checkpoint.ipynb
# 	File: 02-Math-and-Random-Module-checkpoint.ipynb

# %% [markdown]
# ___
# Excellent, you should now be aware of how to work with a computer's files and folders in whichever directory they are in. Remember that the os module works for any oeprating system that supports Python, which means these commands will work across Linux,MacOs, or Windows without need for adjustment.
